# %% [markdown]
# # Flickr API
# A program to obtain photographs from flickr. Specifically, the program will obtain photos of astronauts on the ISS, then return each image accompanied by a description of who's in the photo.

# %%
import flickr_api as flickr
import webbrowser
import sys
import os

# %%
API_KEY = u'49f74fc6ce14613394717c0802508ba0'
API_SECRET = u'd0e40a7e772a3f61'

# %%
def initialize():
    '''
    Prepares the flickr API to get photos.
    '''
    flickr.set_keys(api_key = API_KEY, api_secret = API_SECRET)
    flickr.set_auth_handler(".authFile.txt")

def getUser(username: str):
    '''
    Gets the user id by using the username.

    Keyword Arguments:
    username (string): The user to search for.

    Returns:
    user (obj): a Flickr API user object for the given username.
    '''
    return flickr.Person.findByUserName(username)

def getImagesFromAlbum(user, album : str):
    '''
    Gets the images from a user's albums.  The images
    are written to a new directory with the name of the
    album, along with the descirptions.

    Keyword Arguments:
    user (obj): a Flickr API user object
    album (string): a specific album name

    '''    
    idx = None
    photosets = user.getPhotosets()
    for id,info in enumerate(photosets):
        if (info.title == album):
            idx = id
    if (idx != None):
        albumPhotos = photosets[idx]
        if not os.path.exists(albumPhotos.title):
            print("Creating directory " + albumPhotos.title)
            os.mkdir(albumPhotos.title)
        os.chdir(albumPhotos.title)
        for photo in albumPhotos.getPhotos():
            try:
                print("Saving photo " + photo.title)
                photo.save(photo.title)
                print("Getting photo information...")
                info = photo.getInfo()['description']
                print("Saving photo information...")
                f = open(photo.title+".txt", "w")
                f.write(info)
                f.close()
            except:
                print("Unable to save \"{0}\"".format(photo.title))

def getImages(username : str, album : str):
    '''
    Driver method used to get images from an album.

    Keyword Arguments:
    username (string): The username of the desired user.
    album (string): The name of the desired album to download.
    '''
    initialize()
    user = getUser(username)
    getImagesFromAlbum(user, album)

# %%
if __name__ == "__main__":
    '''
    An example of how to use the module.
    '''
    getImages(username = "NASA on The Commons", album = "International Space Station")
# Out:
# here1
# here4
# here5
# here6
# here2
# here3
# Creating directory International Space Station
# Saving photo Expedition 1 Crew
# Getting photo information...
# Saving photo information...
# Saving photo STS-98 Spacewalkers
# Getting photo information...
# Saving photo information...
# Saving photo Expedition 2 Crew
# Getting photo information...
# Saving photo information...
# Saving photo Expedition 3 Crew
# Getting photo information...
# Saving photo information...
# Saving photo Expedition 12 holiday photo
# Getting photo information...
# Saving photo information...
# Saving photo Expedition 38 Crew
# Getting photo information...
# Saving photo information...
# Saving photo Space Station Mock-up in Neutral Buoyancy Simulator
# Getting photo information...
# Saving photo information...
# Saving photo X-38 Ship 2 in Free Flight
# Getting photo information...
# Saving photo information...
# Saving photo X-38 on B-52 Wing Pylon
# Getting photo information...
# Saving photo information...
# Saving photo X-38 Lakebed Touchdown
# Getting photo information...
# Saving photo information...
# Saving photo X-38 Prototype Lands on Rogers Dry Lakebed
# Getting photo information...
# Saving photo information...
# Saving photo Unity Module in the Payload Bay for STS-88
# Getting photo information...
# Saving photo information...
# Saving photo View of the ISS during Flyaround
# Getting photo information...
# Saving photo information...
# Saving photo Rendezvous with Zarya
# Getting photo information...
# Saving photo information...
# Saving photo Newman Waves at Camera from Unity Module
# Getting photo information...
# Saving photo information...
# Saving photo Soyuz TMA-10M
# Getting photo information...
# Saving photo information...
# Saving photo Soyuz TMA-7
# Getting photo information...
# Saving photo information...
# Saving photo TMA-16
# Getting photo information...
# Saving photo information...
# Saving photo Stephen Frick
# Getting photo information...
# Saving photo information...
# Saving photo Luca Parmitano
# Getting photo information...
# Saving photo information...
# Saving photo Gregory Linteris
# Getting photo information...
# Saving photo information...
# Saving photo Michael Lopez-Alegria
# Getting photo information...
# Saving photo information...
# Saving photo Rex Walheim
# Getting photo information...
# Saving photo information...
# Saving photo Kate Rubins
# Getting photo information...
# Saving photo information...
# Saving photo Oleg Novitskiy
# Getting photo information...
# Saving photo information...
# Saving photo Julie Payette
# Getting photo information...
# Saving photo information...
# Saving photo TMA-3
# Getting photo information...
# Saving photo information...
# Saving photo Steve Robinson
# Getting photo information...
# Saving photo information...
# Saving photo Steve Robinson
# Getting photo information...
# Saving photo information...
# Saving photo Ron Garan
# Getting photo information...
# Saving photo information...
# Saving photo Ron Garan in the ISS Cupola
# Getting photo information...
# Saving photo information...
# Saving photo Andreas Mogensen
# Getting photo information...
# Saving photo information...
# Saving photo Expedition 1
# Getting photo information...
# Saving photo information...
# Saving photo Reid Wiseman
# Getting photo information...
# Saving photo information...
# Saving photo Zarya Module - International Space Station
# Getting photo information...
# Saving photo information...
# Saving photo International Space Station
# Getting photo information...
# Saving photo information...
# Saving photo STS-88 ISS Assembly
# Getting photo information...
# Saving photo information...
# Saving photo Cady Coleman
# Getting photo information...
# Saving photo information...
# Saving photo Steve MacLean
# Getting photo information...
# Saving photo information...
# Saving photo Kenneth Ham
# Getting photo information...
# Saving photo information...
# Saving photo Speed limit
# Getting photo information...
# Saving photo information...
# Saving photo Orbital-1 Mission Antares Launch
# Getting photo information...
# Saving photo information...
# Saving photo SpaceX CRS5 Launch
# Getting photo information...
# Saving photo information...
# Saving photo ISS Partners Tour Kennedy Space Center
# Getting photo information...
# Saving photo information...
# Saving photo Andre Kuipers
# Getting photo information...
# Saving photo information...
# Saving photo Manhattan - 2012
# Getting photo information...
# Saving photo information...
# Saving photo Linnehan during Expedition 16/STS-123 EVA 1
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-08bbb385ec9c> in <module>
#       3     An example of how to use the module.
#       4     '''
# ----> 5     getImages(username = "NASA on The Commons", album = "International Space Station")
#
# <ipython-input-3-aea7b47a4279> in getImages(username, album)
#      66     user = getUser(username)
#      67     print("here3")
# ---> 68     getImagesFromAlbum(user, album)
#      69     print("here4")
#
# <ipython-input-3-aea7b47a4279> in getImagesFromAlbum(user, album)
#      45         for photo in albumPhotos.getPhotos():
#      46             print("Saving photo " + photo.title)
# ---> 47             photo.save(photo.title)
#      48             print("Getting photo information...")
#      49             info = photo.getInfo()['description']
#
# //anaconda3/lib/python3.7/site-packages/flickr_api/objects.py in save(self, filename, size_label)
#    1340         r = urllib.request.urlopen(photo_file)
#    1341
# -> 1342         with open(filename + file_ext, 'wb') as f:
#    1343             f.write(r.read())
#    1344             f.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Linnehan during Expedition 16/STS-123 EVA 1.jpg'
