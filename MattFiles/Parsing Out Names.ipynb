# %%
# Out:
# UsageError: %%time is a cell magic, but the cell body is empty. Did you mean the line magic %time (single %)?

# %%
from selenium import webdriver
from time import sleep
import json
import re as regx
import os

import face_recognition # https://github.com/ageitgey/face_recognition
from PIL import Image # https://pillow.readthedocs.io/en/stable/

# %%
__TESTING_FILEPATH__ = "International Space Station/Expedition 1"
__TESTING_DIRECTORY__ = "International Space Station/"

# %%
lastNames = open("lastNames.txt","r")
    
data = {}
data['names'] = []

for fullName in lastNames:
    data['names'].append({
    'fname': regx.search("\w+(?= )", fullName)[0],
    'lname': regx.search("(?<= )[\w-]+[^.\n]", fullName)[0]
    })
    
with open('lastNames.json', 'w') as outfile:
    json.dump(data, outfile)

# %%
with open('lastNames.json', 'r') as f:
    lastNameDict = json.load(f)

lastNameDict["names"][0]
# Out:
# {'fname': 'joseph', 'lname': 'acaba'}

# %%
def findResults(source):
    people = []
    for i in lastNameDict["names"]:
        re = "({0}) (\w.)*\ ?({1})".format(i["fname"], i["lname"])
        result = regx.search(re, source, regx.IGNORECASE)
        if result is not None:
            people.append(result[0])
        
    re = '|'.join("{}".format(i) for i in people)
    result = regx.findall(re, source)
    
    if regx.search("right to left", source) is not None:
        result.reverse()
    
    return result
     
def readTextFile(fp):
    with open("{}.txt".format(fp), 'r') as file:
        data = file.read()
    return data

def transformCoord(coordinates):
    return (coordinates[3], coordinates[0], coordinates[1], coordinates[2])

def saveFaces(fp, output = "./temp"):
    try:
        os.mkdir(output)
    except:
        print("Path already exists")
    
    imageDesc = readTextFile(fp)
    people = findResults(imageDesc)
    
    photoName = fp.replace(" ", "_")
    photoName = photoName[photoName.find("/"):]
    
    sourePhoto = "{}.jpg".format(fp)
    image = face_recognition.load_image_file(sourePhoto)
    face_locations = face_recognition.face_locations(image)
    
    print("{0}: Found {1} people in the photo and {2} in the description".format(fp, len(face_locations), len(people)))
    
    savedPhotos = {}
    
    for i in range(0, len(face_locations)):
        try:
            tempPhotoName = "{0}{1}-{2}.jpg".format(output, photoName, people[i].replace(" ", "_"))
            savedPhotos[tempPhotoName] = Image.open(sourePhoto).crop(transformCoord(face_locations[i]))
        except:
            print("There was an error saving a file")
            Image.open(sourePhoto).crop(transformCoord(face_locations[i])).show()
    if len(savedPhotos) == len(face_locations):
        print(savedPhotos)
        for name, photo in savedPhotos.items():
            photo.save(name)

# %%
findResults(readTextFile(__TESTING_FILEPATH__))
# Out:
# ['Yuri Gidzenko', 'Sergei Krikalev', 'William M. Shepherd']

# %%
saveFaces(__TESTING_FILEPATH__)
# Out:
# Path already exists
# There was an error saving a file

# %%
for filename in os.listdir(__TESTING_DIRECTORY__):
    if filename.endswith(".jpg"): 
        saveFaces(__TESTING_DIRECTORY__+filename[:-4])
# Out:
# Path already exists
# International Space Station/TMA-08M Landing: Found 11 people in the photo and 1 in the description
# There was an error saving a file
# There was an error saving a file
# There was an error saving a file
# There was an error saving a file
# There was an error saving a file
# There was an error saving a file
# There was an error saving a file
# There was an error saving a file
# There was an error saving a file
# There was an error saving a file
# Path already exists
# International Space Station/Zvezda Launch: Found 0 people in the photo and 931 in the description
# {}
# Path already exists
# International Space Station/New York City on September 11, 2001: Found 0 people in the photo and 1 in the description
# {}
# Path already exists
# International Space Station/Ron Garan: Found 0 people in the photo and 249 in the description
# {}
# Path already exists
# International Space Station/STS-111 Landing: Found 0 people in the photo and 242 in the description
# {}
# Path already exists
# International Space Station/Peggy Whitson: Found 1 people in the photo and 1 in the description
# {'./temp/Peggy_Whitson-Peggy_A._Whitson.jpg': <PIL.Image.Image image mode=RGB size=462x462 at 0x113C06E48>}
# Path already exists
# International Space Station/Launch and entry suits hang in readiness for the STS-111 crew: Found 0 people in the photo and 851 in the description
# {}
# Path already exists
# International Space Station/Soyuz TMA-10M: Found 0 people in the photo and 227 in the description
# {}
# Path already exists
# International Space Station/Expedition 45 Soyuz TMA-17M Landing: Found 1 people in the photo and 2 in the description
# {'./temp/Expedition_45_Soyuz_TMA-17M_Landing-Kjell_Lindgren.jpg': <PIL.Image.Image image mode=RGB size=665x666 at 0x113BFB668>}
# Path already exists
# International Space Station/ISS Partners Tour Kennedy Space Center: Found 25 people in the photo and 2541 in the description
# Path already exists
# International Space Station/Unity Module in the Payload Bay for STS-88: Found 0 people in the photo and 417 in the description
# {}
# Path already exists
# International Space Station/Expedition 1 Crew: Found 4 people in the photo and 3 in the description
# There was an error saving a file
# Path already exists
# International Space Station/Soyuz TMA-18: Found 0 people in the photo and 141 in the description
# {}
# Path already exists
# International Space Station/Artemyev and Skvortsov ISS Spacewalk: Found 0 people in the photo and 1 in the description
# {}
# Path already exists
# International Space Station/X-38 Prototype Lands on Rogers Dry Lakebed: Found 0 people in the photo and 326 in the description
# {}
# Path already exists
# International Space Station/Steve MacLean: Found 1 people in the photo and 1 in the description
# {'./temp/Steve_MacLean-Steve_MacLean.jpg': <PIL.Image.Image image mode=RGB size=155x155 at 0x113C15B70>}
# Path already exists
# International Space Station/Space Station Model: Found 2 people in the photo and 204 in the description
# Path already exists
# International Space Station/Cady Coleman: Found 1 people in the photo and 333 in the description
# {'./temp/Cady_Coleman-.jpg': <PIL.Image.Image image mode=RGB size=385x385 at 0x113C15F28>}
# Path already exists
# International Space Station/Zarya Module - International Space Station: Found 0 people in the photo and 327 in the description
# {}
# Path already exists
# International Space Station/Franklin Chang Diaz: Found 1 people in the photo and 1 in the description
# {'./temp/Franklin_Chang_Diaz-Franklin_Chang-Diaz.jpg': <PIL.Image.Image image mode=RGB size=155x155 at 0x113C06F60>}
# Path already exists
# International Space Station/Oleg Novitskiy: Found 0 people in the photo and 1 in the description
# {}
# Path already exists
# International Space Station/Rex Walheim: Found 1 people in the photo and 1 in the description
# {'./temp/Rex_Walheim-Rex_Walheim.jpg': <PIL.Image.Image image mode=RGB size=63x62 at 0x113C08320>}
# Path already exists
# International Space Station/STS-88 ISS Assembly: Found 0 people in the photo and 269 in the description
# {}
# Path already exists
# International Space Station/TMA-16: Found 0 people in the photo and 1 in the description
# {}
# Path already exists
# International Space Station/Michael Lopez-Alegria: Found 1 people in the photo and 2 in the description
# {'./temp/Michael_Lopez-Alegria-Michael_Lopez-Alegria.jpg': <PIL.Image.Image image mode=RGB size=223x223 at 0x113C15B70>}
# Path already exists
# International Space Station/TMA-3: Found 0 people in the photo and 2 in the description
# {}
# Path already exists
# International Space Station/Soyuz TMA-7: Found 0 people in the photo and 219 in the description
# {}
# Path already exists
# International Space Station/Expedition 28 Landing: Found 0 people in the photo and 605 in the description
# {}
# Path already exists
# International Space Station/Endeavour launches into the night on STS-123: Found 0 people in the photo and 5 in the description
# {}
# Path already exists
# International Space Station/STS-121 Launch: Found 0 people in the photo and 463 in the description
# {}
# Path already exists
# International Space Station/Orbital-1 Mission Antares Launch: Found 0 people in the photo and 580 in the description
# {}
# Path already exists
# International Space Station/Mike Mullane: Found 1 people in the photo and 508 in the description
# {'./temp/Mike_Mullane-.jpg': <PIL.Image.Image image mode=RGB size=385x385 at 0x113C09AC8>}
# Path already exists
# International Space Station/Julie Payette: Found 1 people in the photo and 1 in the description
# {'./temp/Julie_Payette-Julie_Payette.jpg': <PIL.Image.Image image mode=RGB size=462x462 at 0x113BFB668>}
# Path already exists
# International Space Station/Carl Walz: Found 1 people in the photo and 1 in the description
# {'./temp/Carl_Walz-Carl_E._Walz.jpg': <PIL.Image.Image image mode=RGB size=321x321 at 0x113C15F28>}
# Path already exists
# International Space Station/Expedition 1: Found 4 people in the photo and 3 in the description
# There was an error saving a file
# Path already exists
# International Space Station/Steve Robinson: Found 0 people in the photo and 1 in the description
# {}
# Path already exists
# International Space Station/Andre Kuipers: Found 1 people in the photo and 1 in the description
# {'./temp/Andre_Kuipers-Andre_Kuipers.jpg': <PIL.Image.Image image mode=RGB size=462x462 at 0x113C06F60>}
# Path already exists
# International Space Station/Andreas Mogensen: Found 0 people in the photo and 1 in the description
# {}
# Path already exists
# International Space Station/Gregory Linteris: Found 0 people in the photo and 317 in the description
# {}
# Path already exists
# International Space Station/Power Tower Space Station Concept: Found 0 people in the photo and 321 in the description
# {}
# Path already exists
# International Space Station/STS-127 Spacewalk: Found 0 people in the photo and 1 in the description
# {}
# Path already exists
# International Space Station/Artist's Conception of Space Station Freedom: Found 0 people in the photo and 966 in the description
# {}
# Path already exists
# International Space Station/President Obama Calls International Space Station: Found 4 people in the photo and 345 in the description
# Path already exists
# International Space Station/Expedition 13: Found 0 people in the photo and 3 in the description
# {}
# Path already exists
# International Space Station/Reid Wiseman: Found 1 people in the photo and 326 in the description
# {'./temp/Reid_Wiseman-.jpg': <PIL.Image.Image image mode=RGB size=958x958 at 0x113BFBC18>}
# Path already exists
# International Space Station/Expedition 12 holiday photo: Found 2 people in the photo and 2 in the description
# {'./temp/Expedition_12_holiday_photo-William_S._McArthur.jpg': <PIL.Image.Image image mode=RGB size=129x129 at 0x113C1C198>, './temp/Expedition_12_holiday_photo-Valery_I._Tokarev.jpg': <PIL.Image.Image image mode=RGB size=129x129 at 0x113BFBA90>}
# Path already exists
# International Space Station/Great Sandy Desert, Australia: Found 0 people in the photo and 3100 in the description
# {}
# Path already exists
# International Space Station/Roof Space Station Concept: Found 0 people in the photo and 363 in the description
# {}
# Path already exists
# International Space Station/Chris Hadfield: Found 1 people in the photo and 1 in the description
# {'./temp/Chris_Hadfield-Chris_Hadfield.jpg': <PIL.Image.Image image mode=RGB size=1150x1150 at 0x113C09630>}
# Path already exists
# International Space Station/X-38 on B-52 Wing Pylon: Found 0 people in the photo and 481 in the description
# {}
# Path already exists
# International Space Station/SpaceX CRS5 Launch: Found 0 people in the photo and 527 in the description
# {}
# Path already exists
# International Space Station/X-38 Ship 2 in Free Flight: Found 0 people in the photo and 1241 in the description
# {}
# Path already exists
# International Space Station/Soyuz TMA-17 Lands: Found 0 people in the photo and 2 in the description
# {}
# Path already exists
# International Space Station/Randy Bresnik: Found 0 people in the photo and 234 in the description
# {}
# Path already exists
# International Space Station/Expedition 2 Crew: Found 4 people in the photo and 10 in the description
# {'./temp/Expedition_2_Crew-Kent_V._Rominger.jpg': <PIL.Image.Image image mode=RGB size=155x155 at 0x113BFBA90>, './temp/Expedition_2_Crew-Yuri_V._Lonchakov.jpg': <PIL.Image.Image image mode=RGB size=185x186 at 0x113BFB668>, './temp/Expedition_2_Crew-Yury_V._Usachev.jpg': <PIL.Image.Image image mode=RGB size=155x155 at 0x113C06E48>, './temp/Expedition_2_Crew-Umberto_Guidoni.jpg': <PIL.Image.Image image mode=RGB size=129x129 at 0x113C09630>}
# Path already exists
# International Space Station/Expedition 3 Crew: Found 10 people in the photo and 9 in the description
# There was an error saving a file
# Path already exists
# International Space Station/Freedom Space Station Concept: Found 0 people in the photo and 772 in the description
# {}
# Path already exists
# International Space Station/Soyuz TMA-03M and Rassvet: Found 0 people in the photo and 380 in the description
# {}
# Path already exists
# International Space Station/Chris Ferguson: Found 1 people in the photo and 322 in the description
# {'./temp/Chris_Ferguson-.jpg': <PIL.Image.Image image mode=RGB size=665x666 at 0x113BFBA90>}
# Path already exists
# International Space Station/Soyuz TMA-8: Found 0 people in the photo and 3 in the description
# {}
# Path already exists
# International Space Station/STS-106: Found 7 people in the photo and 7 in the description
# {'./temp/STS-106-Daniel_Burbank.jpg': <PIL.Image.Image image mode=RGB size=321x321 at 0x113C06F60>, './temp/STS-106-Edward_Lu.jpg': <PIL.Image.Image image mode=RGB size=267x267 at 0x113C091D0>, './temp/STS-106-Richard_Mastracchio.jpg': <PIL.Image.Image image mode=RGB size=385x385 at 0x113BFB668>, './temp/STS-106-Boris_Morukov.jpg': <PIL.Image.Image image mode=RGB size=267x268 at 0x113C1C438>, './temp/STS-106-Yuri_Malenchenko.jpg': <PIL.Image.Image image mode=RGB size=267x268 at 0x113C15F28>, './temp/STS-106-Terrence_Wilcutt.jpg': <PIL.Image.Image image mode=RGB size=223x223 at 0x113C15B70>, './temp/STS-106-Scott_Altman.jpg': <PIL.Image.Image image mode=RGB size=267x267 at 0x113C09C18>}
# Path already exists
# International Space Station/Space Station Mock-up in Neutral Buoyancy Simulator: Found 0 people in the photo and 913 in the description
# {}
# Path already exists
# International Space Station/Russian Orlan spacesuit underwater spacewalk simulation: Found 0 people in the photo and 1 in the description
# {}
# Path already exists
# International Space Station/STS-131 and Expedition 23 Group Portrait: Found 7 people in the photo and 8 in the description
# {'./temp/STS-131_and_Expedition_23_Group_Portrait-Alan_Poindexter.jpg': <PIL.Image.Image image mode=RGB size=90x90 at 0x113C15F28>, './temp/STS-131_and_Expedition_23_Group_Portrait-James_P._Dutton.jpg': <PIL.Image.Image image mode=RGB size=74x75 at 0x113C15B70>, './temp/STS-131_and_Expedition_23_Group_Portrait-Clayton_Anderson.jpg': <PIL.Image.Image image mode=RGB size=75x75 at 0x113C096A0>, './temp/STS-131_and_Expedition_23_Group_Portrait-Dorothy_Metcalf-Lindenburger.jpg': <PIL.Image.Image image mode=RGB size=89x89 at 0x113C06E48>, './temp/STS-131_and_Expedition_23_Group_Portrait-Stephanie_Wilson.jpg': <PIL.Image.Image image mode=RGB size=74x75 at 0x113C06F60>, './temp/STS-131_and_Expedition_23_Group_Portrait-Naoko_Yamazaki.jpg': <PIL.Image.Image image mode=RGB size=74x75 at 0x113C1C438>, './temp/STS-131_and_Expedition_23_Group_Portrait-Oleg_Kotov.jpg': <PIL.Image.Image image mode=RGB size=75x75 at 0x11E509A20>}
# Path already exists
# International Space Station/Newman Waves at Camera from Unity Module: Found 0 people in the photo and 1 in the description
# {}
# Path already exists
# International Space Station/ATV-1 Jules Verne approaches ISS: Found 0 people in the photo and 682 in the description
# {}
# Path already exists
# International Space Station/International Space Station: Found 0 people in the photo and 252 in the description
# {}
# Path already exists
# International Space Station/Expedition 38 Crew: Found 2 people in the photo and 3 in the description
# {'./temp/Expedition_38_Crew-Oleg_Kotov.jpg': <PIL.Image.Image image mode=RGB size=43x43 at 0x113C08320>, './temp/Expedition_38_Crew-Koichi_Wakata.jpg': <PIL.Image.Image image mode=RGB size=43x43 at 0x113C096A0>}
# Path already exists
# International Space Station/Kate Rubins: Found 0 people in the photo and 1 in the description
# {}
# Path already exists
# International Space Station/Rendezvous with Zarya: Found 0 people in the photo and 407 in the description
# {}
# Path already exists
# International Space Station/Luca Parmitano: Found 1 people in the photo and 1 in the description
# {'./temp/Luca_Parmitano-Luca_Parmitano.jpg': <PIL.Image.Image image mode=RGB size=799x799 at 0x113C09630>}
# Path already exists
# International Space Station/Prime and backup crew for ISS Expedition 13: Found 6 people in the photo and 4 in the description
# There was an error saving a file
# There was an error saving a file
# Path already exists
# International Space Station/Ron Garan in the ISS Cupola: Found 1 people in the photo and 282 in the description
# {'./temp/Ron_Garan_in_the_ISS_Cupola-.jpg': <PIL.Image.Image image mode=RGB size=321x321 at 0x113C06F60>}
# Path already exists
# International Space Station/Soyuz TMA-19 Launch: Found 1 people in the photo and 3 in the description
# {'./temp/Soyuz_TMA-19_Launch-Shannon_Walker.jpg': <PIL.Image.Image image mode=RGB size=129x129 at 0x113C08320>}
# Path already exists
# International Space Station/Soyuz TMA-08M: Found 0 people in the photo and 1 in the description
# {}
# Path already exists
# International Space Station/STS-96 Launch: Found 0 people in the photo and 579 in the description
# {}
# Path already exists
# International Space Station/Manhattan - 2012: Found 2 people in the photo and 212 in the description
# Path already exists
# International Space Station/View of Turkey from the ISS Cupola: Found 0 people in the photo and 527 in the description
# {}
# Path already exists
# International Space Station/View of the ISS during Flyaround: Found 0 people in the photo and 2 in the description
# {}
# Path already exists
# International Space Station/Kenneth Ham: Found 2 people in the photo and 1 in the description
# There was an error saving a file
# Path already exists
# International Space Station/John Herrington: Found 1 people in the photo and 1 in the description
# {'./temp/John_Herrington-John_Herrington.jpg': <PIL.Image.Image image mode=RGB size=958x958 at 0x113BFBA90>}
# Path already exists
# International Space Station/X-38 Lakebed Touchdown: Found 0 people in the photo and 408 in the description
# {}
# Path already exists
# International Space Station/Speed limit: Found 2 people in the photo and 1 in the description
# There was an error saving a file
# Path already exists
# International Space Station/STS-98 Spacewalkers: Found 2 people in the photo and 2 in the description
# {'./temp/STS-98_Spacewalkers-Thomas_D._Jones.jpg': <PIL.Image.Image image mode=RGB size=462x462 at 0x113C06E48>, './temp/STS-98_Spacewalkers-Robert_L._Curbeam.jpg': <PIL.Image.Image image mode=RGB size=462x462 at 0x113C091D0>}
# Path already exists
# International Space Station/Photo of Hermann Oberth: Found 1 people in the photo and 720 in the description
# {'./temp/Photo_of_Hermann_Oberth-.jpg': <PIL.Image.Image image mode=RGB size=1988x1988 at 0x113C06F60>}
# Path already exists
# International Space Station/Stephen Frick: Found 1 people in the photo and 1 in the description
# {'./temp/Stephen_Frick-Stephen_N._Frick.jpg': <PIL.Image.Image image mode=RGB size=555x555 at 0x113BFB668>}
